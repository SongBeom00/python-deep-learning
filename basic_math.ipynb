# %%
import math
import matplotlib.style
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('seaborn-v0_8-whitegrid')

# %%
def linear_function(x):
    a=0.5
    b=2
    
    return a*x+b

print(linear_function(5))
# Out:
# 4.5

# %%
x = np.arange(-5,5,0.1)
y = linear_function(x)

plt.plot(x,y)
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear_Function')
# Out:
# Text(0.5, 1.0, 'Linear_Function')

# %%
def quadratic_function(x) : 
    a = 1
    b = -1
    c= -2

    return a*x**2 + b*x + c

# %%
print(quadratic_function(2))
# Out:
# 0

# %%
x = np.arange(-5,5,0.1)

y = quadratic_function(x)

plt.plot(x,y)

# %%
def cubic_function(x) :
    a=4
    b=0
    c=-1
    d=-8

    return a*x**3 + b*x**2 + c*x + d

# %%
print(cubic_function(3))
# Out:
# 97

# %%
x = np.arange(-5,5,0.1)

y = cubic_function(x)

plt.plot(x,y)

# %%
def my_func(x) :
    a=1
    b=-3
    c=10
    return a*x**2 + b*x + c

# %%
x = np.arange(-10,10,0.1)

y = my_func(x)

plt.plot(x,y)
plt.scatter(1.5,my_func(1.5))
plt.text(1.5-1.5,my_func(1.5)+10,f'min value of f(x) {1.5}, {my_func(1.5)}',fontsize=10)
# Out:
# Text(0.0, 17.75, 'min value of f(x) 1.5, 7.75')

# %%
min_val = min(y)
print(min_val)
# Out:
# 7.75

# %%
def get_mininum(x1,x2,f) :
    x = np.arange(x1,x2,0.01)
    y= f(x)

    plt.plot(x,y)

    return min(y)

# %%
print(get_mininum(1,4,my_func))
# Out:
# 7.75

# %%
def exponetial_function(x) :
    a = 4
    return a**x

# %%
print(exponetial_function(4))
print(exponetial_function(0))
# Out:
# 256
# 1

# %%
x = np.arange(-3,2,0.1)

y = exponetial_function(x)

plt.plot(x,y)
plt.xlim(-4,3)
plt.ylim(-1,15)
# Out:
# (-1.0, 15.0)

# %%
def exponetial_function2(x) :
    a = 4
    return np.power(a,x)

# %%
print(exponetial_function2(4))
print(exponetial_function2(0))
# Out:
# 256
# 1

# %%
x = np.arange(-2,5,0.1)

y = exponetial_function2(x)

plt.plot(x,y)

# %%
print(math.exp(4))

print(np.exp(4))
# Out:
# 54.598150033144236
# 54.598150033144236

# %%
print(math.log(2,3))
print(np.log2(4))
print(np.log(4))
# Out:
# 0.6309297535714574
# 2.0
# 1.3862943611198906

# %%
x= np.arange(-1,5,0.01)

y1 = np.exp(x)

x2 = np.arange(0.00001,5,0.01)
y2 = np.log(x2)

y3 =x

plt.plot(x,y1,'--r',x2,y2,'b-',x,y3,'k--')

plt.ylim(-2,6)
plt.axvline(x=0,color='k')
plt.axhline(y=0,color='k')

# %%
x = np.arange(-10,10,0.01)
y1 = -np.log(x)
y2 = -np.log(1-x)

plt.axvline(x=0,color='k')
plt.axhline(y=0,color='k')

plt.grid()
plt.plot(x,y1,'b-',x,y2,'r-')
plt.text(0.9,2.0,'y=-log(1-x)',fontsize=15)
plt.text(0.1,3,'y=-log(x)',fontsize=15)
plt.xlim(-0.3,1.4)
plt.ylim(-0.5,4)
plt.scatter(0.5,-np.log(0.5))
plt.show()
# Out:
# C:\Users\kjb00\AppData\Local\Temp\ipykernel_9476\360578692.py:2: RuntimeWarning: invalid value encountered in log
#   y1 = -np.log(x)
# C:\Users\kjb00\AppData\Local\Temp\ipykernel_9476\360578692.py:3: RuntimeWarning: invalid value encountered in log
#   y2 = -np.log(1-x)

# %%
from sympy import *
init_printing()

x,y,z = symbols('x y z')
a,b,c,t = symbols('a b c t')

# %%
print(f"극한값 :",limit((x**3-1)/(x-1),x,1))

plot((x**3-1)/(x-1),xlim=(-5,5), ylim=(-1,10))
# Out:
# 극한값 : 3

# %%
print(limit((1+x)/x,x,oo))

plot((1+x)/x,xlim=(-10,10),ylim=(-5,5))
# Out:
# 1

# %%
print(limit(sqrt(x+3)-2/x-1,x,1))

plot((sqrt(x+3)-2)/(x-1),xlim=(-5,12),ylim=(-0.5,1))
# Out:
# -1

# %%
print(limit(tan(x),x,pi/2,'+'))

print(limit(tan(x),x,pi/2,'-'))


plot(tan(x),xlim=(-3.14,3.14),ylim=(-6,6))
# Out:
# -oo
# oo

# %%
print(limit(sin(x)/x,x,0))

plot(sin(x)/x,ylim=(-2,2))
# Out:
# 1

# %%
print(limit(x*sin(1/x),x,0))

plot(x*sin(1/x),xlim=(-2,2),ylim=(-1,1.5))
# Out:
# 0

# %%
print(limit((2**x-2**(-x))/(2**x+2**(-x)),x,oo))

plot((2**x-2**(-x))/(2**x+2**(-x)),xlim=(-10,10),ylim=(-3,3))
# Out:
# 1

# %%
print(limit(log(x+1,2)-log(x,2),x,oo))

plot(log(x,2),log(x+1,2),xlim=(-4,6),ylim=(-4,4) )
# Out:
# 0

# %%
print(limit((1+1/x)**x,x,oo))
print(limit((1+2/x)**x,x,oo))
print(limit((exp(x)-1)/x,x,0))
print(limit(ln(1+x)/x,x,0))

plot(ln(1+x)/x,xlim=(-4,6),ylim=(-2,8))
# Out:
# E
# exp(2)
# 1
# 1

# %%
def numerical_differential(f,x) :
    h = 1e-4
    return (f(x+h)-f(x-h))/(2*h)

# %%
def my_func(x) :
    return 2*x**2 + 3*x + 2

# %%
def linear_func(a,b,c,x) :
    return c*(x-a)+b

# %%
c = numerical_differential(my_func,1)

x= np.arange(-5,5,0.01)
y=linear_func(1,my_func(1),c,x)

plt.xlabel('x')
plt.ylabel('y')
plt.scatter(1,my_func(1))
plt.plot(x,my_func(x),x,y,'r-')
plt.title('f(x) & linear function')
plt.show()

# %%
def my_func2(x) :
    return (x[0]**2 + x[1]**2)

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

# X, Y 값의 범위를 설정합니다.
x = np.arange(-4.0, 4.0, 0.4)
y = np.arange(-4.0, 4.0, 0.4)

# 메쉬 그리드를 만듭니다.
X, Y = np.meshgrid(x, y)

# Z 값은 X와 Y의 제곱을 더한 것입니다.
Z = X**2 + Y**2

# 3D 플롯을 위한 Figure와 Axes 객체를 생성합니다.
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 표면 그래프를 그립니다.
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='coolwarm')

# 그래프에 제목을 추가합니다.
ax.set_title('f(x, y) = x**2 + y**2')

# 그래프를 표시합니다.
plt.show()

# %%
x = np.array([1,2])
def f0_function(x0) :
    return (x0**2) + (2**2)

print(numerical_differential(f0_function,x[0]))
# Out:
# 1.9999999999997797

# %%
def f1_function(x1) :
    return (1**2) + (x1**2)

print(numerical_differential(f1_function,x[1]))
# Out:
# 4.000000000004

# %%
def numerical_diff(f,x) :
    h=1e-5
    grad = np.zeros_like(x)

    for i in range(x.size):
        tmp = x[i]

        x[i] = tmp+h
        fxh1 = f(x)

        x[i]=tmp-h
        fxh2 = f(x)

        grad[i] = (fxh1-fxh2) / (2*h)
        x[i] = tmp

    return grad

# %%
print(numerical_diff(my_func2,np.array([3.0,4.0])))
# Out:
# [6. 8.]

# %%
def step_fun(x) :
    if x>0 :
        return 1
    else :
        return 0

# %%
import numpy as np

def step_fun_for_numpy(x):
    y =np.array(x>0)
    return y.astype(np.int32)  # astype는 소문자로 사용해야 합니다.

# %%
print(step_fun(-3))
print(step_fun_for_numpy(6))
# Out:
# 0
# 1

# %%
def sigmoid(x) :
    return 1 / (1+np.exp(-x))

# %%
print(sigmoid(3))
print(sigmoid(-3))
# Out:
# 0.9525741268224334
# 0.04742587317756678

# %%
x = np.arange(-5,5,0.1)
y = sigmoid(x)

plt.plot(x,y)

# %%
plt.grid()
x = np.arange(-5.0,5.0,0.01)
y1 = sigmoid(x)
y2 = step_fun_for_numpy(x)
plt.plot(x,y1,'r-',x,y2,'b--')
plt.show()

# %%
def step_fun1(x) :
    y = np.array(x>0)
    return y.astype(int)

def sigmoid1(x) :
    return 1 / (1+np.exp(-x))

# %%
print(step_fun1(3))
print(sigmoid1(3))
# Out:
# 1
# 0.9525741268224334

# %%
x = np.arange(-5.0,5.0,0.01)

y1 = sigmoid1(x)
y2 = step_fun1(x)

plt.plot(x,y1,'r-',x,y2,'b-')
# Out:
# [<matplotlib.lines.Line2D at 0x26ff1244fb0>,
#  <matplotlib.lines.Line2D at 0x26ff1247830>]

# %%
def ReLU(x) :
    return np.maximum(0,x)

# %%
print(ReLU(5))
print(ReLU(-3))
# Out:
# 5
# 0

# %%
x = np.arange(-5,5,0.1)

y = ReLU(x)

plt.plot(x,y)

# %%
def tanh(x) :
    return (np.exp(x)-np.exp(-x)) / (np.exp(x) + np.exp(-x))

# %%
print(tanh(3))
print(tanh(-3))
# Out:
# 0.9950547536867306
# -0.9950547536867306

# %%
x = np.arange(-3,3,0.1)
y = tanh(x)

plt.plot(x,y)
plt.axhline(y=0,color='k')

# %%
def indentify_fun(x) :
    return x

# %%
x =np.array([2,-3,0.4])

print(indentify_fun(x))
# Out:
# [ 2.  -3.   0.4]

# %%
def softmax(a) :
    exp_a = np.exp(a)
    sum_exp_a = np.sum(exp_a)
    y = exp_a/sum_exp_a
    return y

# %%
a = np.array([0.3,0.2,4.0,-1.2])

print(softmax(a))
print(sum(softmax(a)))
# Out:
# [0.02348781 0.02125265 0.9500187  0.00524084]
# 1.0

# %%
A = np.array([1000,900,1050,500])
print(softmax(A))
# Out:
# [nan nan nan  0.]
# C:\Users\kjb00\AppData\Local\Temp\ipykernel_9476\1682933598.py:2: RuntimeWarning: overflow encountered in exp
#   exp_a = np.exp(a)
# C:\Users\kjb00\AppData\Local\Temp\ipykernel_9476\1682933598.py:4: RuntimeWarning: invalid value encountered in divide
#   y = exp_a/sum_exp_a

# %%
def softmax1(a) :
    C = np.max(a)
    return (np.exp(a-C) / np.sum(np.exp(a-C)))

# %%
A = np.array([1000,900,1050,500])
print(softmax1(A))
# Out:
# [1.92874985e-022 7.17509597e-066 1.00000000e+000 1.37415257e-239]

# %%
def Leaky_ReLU(x) :
    a=0.01
    return np.maximum(a*x,x)

# %%
x = np.array([0.5,-1.4,3,0,5])
x1 = np.arange(-5,5,0.1)
print(Leaky_ReLU(x))

plt.plot(x1,Leaky_ReLU(x1))
# Out:
# [ 0.5   -0.014  3.     0.     5.   ]

# %%
def ELU(x) :
    alpha = 1.0
    return (x>=0) * x + (x<0) *alpha*(np.exp(x)-1)

# %%
print(ELU(4))
print(ELU(-0.5))
# Out:
# 4.0
# -0.3934693402873666

# %%
def sigmoid(x) :
    return 1 / (1+np.exp(-x))

# %%
X = np.array([1.0,0.5,0.4])
W1 = np.array([[0.1,0.3,0.5],[0.2,0.4,0.6],[0.3,0.5,0.7]])
B1 = np.array([1,1,1])

print(X.shape)
print(W1.shape)
print(B1.shape)

A1 = np.dot(X,W1)+B1
Z1 = sigmoid(A1)

print(A1)
print(Z1)
# Out:
# (3,)
# (3, 3)
# (3,)
# [1.32 1.7  2.08]
# [0.78918171 0.84553473 0.88894403]

# %%
W2 = np.array([[0.2,0.4,0.6],[0.1,0.3,0.5],[0.4,0.6,0.8]])
B2 = np.array([1,1,1])

print(W2.shape)
print(B2.shape)

A2 = np.dot(A1,W2)+B2
Z2 = sigmoid(A2)

print(A2)
print(Z2)
# Out:
# (3, 3)
# (3,)
# [2.266 3.286 4.306]
# [0.90602176 0.96394539 0.9866921 ]

# %%
W3 = np.array([[0.1,0.3],[-0.1,-0.5],[0.3,0.5]])
B3 = np.array([1,1])

print(W3.shape)
print(B3.shape)

A3 = np.dot(A2,W3)+B3
Z3 = sigmoid(A3)

print(A3)
print(Z3)
# Out:
# (3, 2)
# (2,)
# [2.1898 2.1898]
# [0.8993298 0.8993298]

# %%
W4 = np.array([[0.1,0.2],[0.3,0.5]])
B4 = np.array([1,1])

print(W4.shape)
print(B4.shape)

A4 = np.dot(A3,W4)+B4
Y= sigmoid(A4)

print(A4)
print(Y)
# Out:
# (2, 2)
# (2,)
# [1.87592 2.53286]
# [0.86714179 0.92641356]
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
